# %%
import numpy as np
import pandas as pd
from IPython.display import display

# %%
resfinder = pd.read_table('C:/Users/diogo/Desktop/ARG_search/WasteWater/resfinder/SRR1237782_rf/ResFinder_results_tab.txt')
card = pd.read_table('C:/Users/diogo/Desktop/ARG_search/WasteWater/card_rgi/SRR1237782_card/SRR1237782_card.txt')

# %% [markdown]
# Resfinder

# %%
resfinder_clean = resfinder.drop(columns=['Alignment Length/Gene Length', 'Position in reference'])
resfinder_new = resfinder_clean.rename(columns={'Accession no.': 'Accession_rf', 'Position in contig': 'Position_in_contig',
                                                'Resistance gene': 'Resistance_gene', 'Coverage': 'Nucleotide_Coverage'})
resfinder_standard = resfinder_new.assign(AMR_Gene_Family=np.nan, Accession_card=np.nan, Resistance_Mechanism=np.nan, Protein_Coverage=np.nan)
resfinder_final = resfinder_standard.reindex(sorted(resfinder_standard.columns), axis=1)

# %% [markdown]
# Card

# %%
card_clean = card.drop(columns=['ORF_ID', 'Orientation', 'Cut_Off', 'Pass_Bitscore', 'Best_Hit_Bitscore', 'Model_type', 'SNPs_in_Best_Hit_ARO',
                                'Other_SNPs', 'Predicted_DNA', 'Predicted_Protein', 'CARD_Protein_Sequence',
                                'ID', 'Model_ID', 'Nudged', 'Note'])
card_new = card_clean.rename(columns={'AMR Gene Family': 'AMR_Gene_Family', 'Best_Hit_ARO': 'Resistance_gene', 'Drug Class': 'Phenotype',
                                      'Best_Identities': 'Identity', 'ARO': 'Accession_card', 'Resistance Mechanism': 'Resistance_Mechanism',
                                      'Percentage Length of Reference Sequence': 'Protein_Coverage'})
card_standard = card_new.assign(Accession_rf=np.nan, Nucleotide_Coverage=np.nan)
card_last = card_standard.reindex(sorted(card_standard.columns), axis=1)
card_last["Position_in_contig"] = card_last.Start.astype(str).str.cat(card_last.Stop.astype(str), sep="..")
card_final = card_last.drop(columns=["Start", "Stop"])

# %% [markdown]
# Df combinado

# %%
final_df = pd.concat([resfinder_final, card_final])
#print(final_df)
header=list(final_df.columns)
#print(header)
#final_df.to_csv(r'/Users/diogo/Desktop/final_df.csv', columns=header, index=False)
display(final_df)
# Out:
#                                       AMR_Gene_Family  Accession_card  \
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                 NaN             NaN
# 3                                                 NaN             NaN
# 4                                                 NaN             NaN
# 0   resistance-nodulation-cell division (RND) anti...       3000777.0
# 1   antibiotic-resistant isoleucyl-tRNA synthetase...       3003730.0
# 2   resistance-nodulation-cell division (RND) anti...       3000830.0
# 3   small multidrug resistance (SMR) antibiotic ef...       3004039.0
# 4   tetracycline-resistant ribosomal protection pr...       3000186.0
# 5   resistance-nodulation-cell division (RND) anti...       3000656.0
# 6   resistance-nodulation-cell division (RND) anti...       3000499.0
# 7                 pmr phosphoethanolamine transferase       3003578.0
# 8   major facilitator superfamily (MFS) antibiotic...       3000833.0
# 9   major facilitator superfamily (MFS) antibiotic...       3000832.0
# 10  major facilitator superfamily (MFS) antibiotic...       3000206.0
# 11  major facilitator superfamily (MFS) antibiotic...       3000254.0
# 12  resistance-nodulation-cell division (RND) anti...       3000502.0
# 13  resistance-nodulation-cell division (RND) anti...       3000499.0
# 14  rifamycin-resistant beta-subunit of RNA polyme...       3004480.0
# 15                           ampC-type beta-lactamase       3004612.0
# 16  resistance-nodulation-cell division (RND) anti...       3000216.0
# 17  resistance-nodulation-cell division (RND) anti...       3000795.0
# 18  major facilitator superfamily (MFS) antibiotic...       3003550.0
# 19  major facilitator superfamily (MFS) antibiotic...       3003549.0
# 20  major facilitator superfamily (MFS) antibiotic...       3001328.0
# 21  antibiotic-resistant isoleucyl-tRNA synthetase...       3003730.0
# 22  resistance-nodulation-cell division (RND) anti...       3000518.0
# 23                          sulfonamide resistant sul       3000410.0
# 24  major facilitator superfamily (MFS) antibiotic...       3005010.0
# 25  trimethoprim resistant dihydrofolate reductase...       3002862.0
# 26  rifamycin-resistant beta-subunit of RNA polyme...       3004480.0
# 27  resistance-nodulation-cell division (RND) anti...       3000491.0
# 28  ATP-binding cassette (ABC) antibiotic efflux pump       3003952.0
# 29  tetracycline-resistant ribosomal protection pr...       3004442.0
#
#    Accession_rf                                   Contig  Identity  \
# 0        U12338      NODE_13397_length_2072_cov_1.881011    100.00
# 1      FN433596      NODE_14079_length_2001_cov_3.516444     99.74
# 2      AJ419170      NODE_13397_length_2072_cov_1.881011     98.91
# 3      FJ460238      NODE_13889_length_2022_cov_2.046772    100.00
# 4        X68232      NODE_13397_length_2072_cov_1.881011     99.65
# 0           NaN     NODE_313_length_19715_cov_5.260631_4     42.27
# 1           NaN    NODE_2170_length_7155_cov_3.282113_1      98.63
# 2           NaN     NODE_2673_length_6227_cov_2.515554_2    100.00
# 3           NaN     NODE_4122_length_4643_cov_1.901700_3     98.18
# 4           NaN    NODE_4211_length_4575_cov_2.668142_6     100.00
# 5           NaN     NODE_4769_length_4199_cov_2.576014_5    100.00
# 6           NaN    NODE_4769_length_4199_cov_2.576014_6      99.44
# 7           NaN     NODE_5157_length_3972_cov_2.218535_2     99.69
# 8           NaN    NODE_6509_length_3382_cov_2.055305_1      97.79
# 9           NaN     NODE_6509_length_3382_cov_2.055305_2    100.00
# 10          NaN     NODE_6509_length_3382_cov_2.055305_3     99.72
# 11          NaN    NODE_6509_length_3382_cov_2.055305_4      99.22
# 12          NaN    NODE_7038_length_3212_cov_2.105163_1      99.57
# 13          NaN    NODE_7038_length_3212_cov_2.105163_2      99.29
# 14          NaN   NODE_8270_length_2877_cov_28.142807_4     100.00
# 15          NaN     NODE_8463_length_2834_cov_1.875855_1     99.73
# 16          NaN    NODE_9412_length_2639_cov_2.515093_1     100.00
# 17          NaN   NODE_10210_length_2501_cov_2.336468_4      99.22
# 18          NaN   NODE_11773_length_2272_cov_1.873252_1      98.55
# 19          NaN   NODE_11773_length_2272_cov_1.873252_2      98.76
# 20          NaN   NODE_12332_length_2196_cov_1.843064_3      96.05
# 21          NaN   NODE_12691_length_2153_cov_2.863203_3      99.09
# 22          NaN    NODE_13214_length_2092_cov_2.911144_2     99.52
# 23          NaN    NODE_13397_length_2072_cov_1.881011_2    100.00
# 24          NaN    NODE_13397_length_2072_cov_1.881011_3    100.00
# 25          NaN   NODE_13397_length_2072_cov_1.881011_4     100.00
# 26          NaN  NODE_13502_length_2060_cov_41.390025_1      99.13
# 27          NaN   NODE_13741_length_2034_cov_2.402729_1     100.00
# 28          NaN   NODE_14045_length_2005_cov_2.213333_2      99.22
# 29          NaN    NODE_14079_length_2001_cov_3.516444_1     67.89
#
#     Nucleotide_Coverage                                          Phenotype  \
# 0            100.000000                            Sulphonamide resistance
# 1             81.041667                            Tetracycline resistance
# 2             79.824561                            Trimethoprim resistance
# 3             90.506329                            Trimethoprim resistance
# 4             84.684685                            Disinfectant resistance
# 0                   NaN  fluoroquinolone antibiotic; tetracycline antib...
# 1                   NaN                                          mupirocin
# 2                   NaN  aminoglycoside antibiotic; aminocoumarin antib...
# 3                   NaN                               macrolide antibiotic
# 4                   NaN                            tetracycline antibiotic
# 5                   NaN  fluoroquinolone antibiotic; cephalosporin; gly...
# 6                   NaN  fluoroquinolone antibiotic; cephalosporin; cep...
# 7                   NaN                                 peptide antibiotic
# 8                   NaN  macrolide antibiotic; fluoroquinolone antibiot...
# 9                   NaN  macrolide antibiotic; fluoroquinolone antibiot...
# 10                  NaN                            tetracycline antibiotic
# 11                  NaN                            tetracycline antibiotic
# 12                  NaN  fluoroquinolone antibiotic; cephalosporin; cep...
# 13                  NaN  fluoroquinolone antibiotic; cephalosporin; cep...
# 14                  NaN                               rifamycin antibiotic
# 15                  NaN                               cephalosporin; penam
# 16                  NaN  fluoroquinolone antibiotic; cephalosporin; gly...
# 17                  NaN  macrolide antibiotic; fluoroquinolone antibiot...
# 18                  NaN                nucleoside antibiotic; acridine dye
# 19                  NaN                nucleoside antibiotic; acridine dye
# 20                  NaN  tetracycline antibiotic; benzalkonium chloride...
# 21                  NaN                                          mupirocin
# 22                  NaN  macrolide antibiotic; fluoroquinolone antibiot...
# 23                  NaN                             sulfonamide antibiotic
# 24                  NaN                                       acridine dye
# 25                  NaN                       diaminopyrimidine antibiotic
# 26                  NaN                               rifamycin antibiotic
# 27                  NaN                          aminoglycoside antibiotic
# 28                  NaN                                 peptide antibiotic
# 29                  NaN                            tetracycline antibiotic
#
#    Position_in_contig  Protein_Coverage  \
# 0           304..1143               NaN
# 1             1..1556               NaN
# 2          1614..2072               NaN
# 3              1..429               NaN
# 4          1203..1484               NaN
# 0          2195..5386            100.38
# 1              3..224              6.68
# 2           356..1729            100.00
# 3          1110..1442            100.00
# 4          4063..4575             26.60
# 5          2605..3267            100.00
# 6          3666..4199             46.23
# 7          1500..2468            100.00
# 8              3..410             11.36
# 9           415..1029            100.00
# 10         1445..2608            110.26
# 11         2608..3381             50.39
# 12            3..2774             89.36
# 13         2786..3211             36.62
# 14         2556..2876              9.02
# 15            3..1097             94.81
# 16             2..940             29.74
# 17         2116..2499             33.25
# 18             1..825             56.35
# 19          822..2270             70.57
# 20         1512..2195             55.61
# 21         1165..2151             29.63
# 22          818..1450            100.00
# 23          304..1143            100.00
# 24         1137..1484            100.00
# 25         1714..2070             75.16
# 26            1..2058             57.84
# 27            3..1829             58.73
# 28         1234..2004             46.80
# 29            3..1556             81.06
#
#                                  Resistance_Mechanism  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 0                                   antibiotic efflux
# 1                        antibiotic target alteration
# 2                                   antibiotic efflux
# 3                                   antibiotic efflux
# 4                        antibiotic target protection
# 5                                   antibiotic efflux
# 6                                   antibiotic efflux
# 7                        antibiotic target alteration
# 8                                   antibiotic efflux
# 9                                   antibiotic efflux
# 10                                  antibiotic efflux
# 11                                  antibiotic efflux
# 12                                  antibiotic efflux
# 13                                  antibiotic efflux
# 14  antibiotic target alteration; antibiotic targe...
# 15                            antibiotic inactivation
# 16                                  antibiotic efflux
# 17                                  antibiotic efflux
# 18                                  antibiotic efflux
# 19                                  antibiotic efflux
# 20                                  antibiotic efflux
# 21                       antibiotic target alteration
# 22                                  antibiotic efflux
# 23                      antibiotic target replacement
# 24                                  antibiotic efflux
# 25                      antibiotic target replacement
# 26  antibiotic target alteration; antibiotic targe...
# 27                                  antibiotic efflux
# 28                                  antibiotic efflux
# 29                       antibiotic target protection
#
#                                       Resistance_gene
# 0                                                sul1
# 1                                              tet(M)
# 2                                               dfrA7
# 3                                              dfrA17
# 4                                                qacE
# 0                                                adeF
# 1   Bifidobacterium bifidum ileS conferring resist...
# 2                                                cpxA
# 3                               Escherichia coli emrE
# 4                                                tetM
# 5                                                AcrS
# 6                                                AcrE
# 7                                                PmrF
# 8                                                evgS
# 9                                                evgA
# 10                                               emrK
# 11                                               emrY
# 12                                               AcrF
# 13                                               AcrE
# 14  Bifidobacterium adolescentis rpoB mutants conf...
# 15               Escherichia coli ampH beta-lactamase
# 16                                               acrB
# 17                                               mdtE
# 18                                               mdtP
# 19                                               mdtO
# 20                              Escherichia coli mdfA
# 21  Bifidobacterium bifidum ileS conferring resist...
# 22                                                CRP
# 23                                               sul1
# 24                                         qacEdelta1
# 25                                              dfrA7
# 26  Bifidobacterium adolescentis rpoB mutants conf...
# 27                                               acrD
# 28                                               YojI
# 29                                         tet(W/N/W)
