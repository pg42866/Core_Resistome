# %%
import numpy as np
import pandas as pd
from IPython.display import display

# %%
resfinder = pd.read_table('C:/Users/diogo/Desktop/ARG_search/WasteWater/resfinder/SRR1237782_rf/ResFinder_results_tab.txt')
card = pd.read_table('C:/Users/diogo/Desktop/ARG_search/WasteWater/card_rgi/SRR1237782_card/SRR1237782_card.txt')

# %% [markdown]
# Resfinder

# %%
resfinder_clean = resfinder.drop(columns=['Alignment Length/Gene Length', 'Coverage', 'Position in reference'])
resfinder_new = resfinder_clean.rename(columns={'Accession no.': 'Accession_rf', 'Position in contig': 'Position_in_contig', 'Resistance gene': 'Resistance_gene'})
resfinder_standard = resfinder_new.assign(AMR_Gene_Family=np.nan, Accession_card=np.nan, Resistance_Mechanism=np.nan)
resfinder_final = resfinder_standard.reindex(sorted(resfinder_standard.columns), axis=1)
#print(resfinder_final)

# %% [markdown]
# Card

# %%
card_clean = card.drop(columns=['ORF_ID', 'Orientation', 'Cut_Off', 'Pass_Bitscore', 'Best_Hit_Bitscore', 'Model_type', 'SNPs_in_Best_Hit_ARO', 'Other_SNPs', 'Predicted_DNA', 'Predicted_Protein', 'CARD_Protein_Sequence', 'Percentage Length of Reference Sequence', 'ID', 'Model_ID', 'Nudged', 'Note'])
card_new = card_clean.rename(columns={'AMR Gene Family': 'AMR_Gene_Family', 'Best_Hit_ARO': 'Resistance_gene', 'Drug Class': 'Phenotype', 'Best_Identities': 'Identity', 'ARO': 'Accession_card', 'Resistance Mechanism': 'Resistance_Mechanism'})
card_standard = card_new.assign(Accession_rf=np.nan)
#card_standard = card_new.assign(Accession_rf=np.nan, Position_in_contig=np.nan)
card_last = card_standard.reindex(sorted(card_standard.columns), axis=1)
card_last["Position_in_contig"] = card_last.Start.astype(str).str.cat(card_last.Stop.astype(str), sep="..")
card_final = card_last.drop(columns=["Start", "Stop"])

# %% [markdown]
# Df combinado

# %%
final_df = pd.concat([resfinder_final, card_final])
#print(final_df)
header=list(final_df.columns)
#final_df.to_csv(r'/Users/diogo/Desktop/final_df.csv', columns = header, index = False)
display(final_df)
# Out:
#                                       AMR_Gene_Family  Accession_card  \
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                 NaN             NaN
# 3                                                 NaN             NaN
# 4                                                 NaN             NaN
# 0   resistance-nodulation-cell division (RND) anti...       3000777.0
# 1   antibiotic-resistant isoleucyl-tRNA synthetase...       3003730.0
# 2   resistance-nodulation-cell division (RND) anti...       3000830.0
# 3   small multidrug resistance (SMR) antibiotic ef...       3004039.0
# 4   tetracycline-resistant ribosomal protection pr...       3000186.0
# 5   resistance-nodulation-cell division (RND) anti...       3000656.0
# 6   resistance-nodulation-cell division (RND) anti...       3000499.0
# ...
